# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      ----- ---------------------------------- 30.7/232.6 kB ? eta -:--:--
#      --------- --------------------------- 61.4/232.6 kB 812.7 kB/s eta 0:00:01
#      ------------------ ------------------- 112.6/232.6 kB 1.1 MB/s eta 0:00:01
#      ---------------------- ------------- 143.4/232.6 kB 944.1 kB/s eta 0:00:01
#      ---------------------- ------------- 143.4/232.6 kB 944.1 kB/s eta 0:00:01
#      ---------------------------------- - 225.3/232.6 kB 981.9 kB/s eta 0:00:01
#      ---------------------------------- - 225.3/232.6 kB 981.9 kB/s eta 0:00:01
#      ------------------------------------ 232.6/232.6 kB 710.3 kB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

with open('ejemplo.pdf', 'rb') as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)

    num_pages = len(pdf_reader.pages)

    for page_num in range(num_pages):
        page = pdf_reader.pages[page_num]
        text = page.extract_text()
        print(text)
# Out:
# Hola buenos días, esta es la clase del profe Luis Villafaña con Python:)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel('CAMPA2023.xlsx')

print(df.head())
# Out:
#    1     Cristel Bolio
# 0  2      Dara Quiroga
# 1  3      Toño Garrido
# 2  4   David Dominguez
# 3  5      Eliezer Pech
# 4  6  Emmanuel Garrido

# %%
pip install python-docx
# Out:
# Collecting python-docx
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/5f/d8/6948f7ac00edf74bfa52b3c5e3073df20284bec1db466d13e668fe991707/python_docx-1.1.0-py3-none-any.whl.metadata
#   Downloading python_docx-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in d:\anaconda\lib\site-packages (from python-docx) (4.9.2)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from python-docx) (4.7.1)
# Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.6 kB ? eta -:--:--
#    ----- ---------------------------------- 30.7/239.6 kB 1.3 MB/s eta 0:00:01
#    ------ -------------------------------- 41.0/239.6 kB 487.6 kB/s eta 0:00:01
#    ------------------- ------------------ 122.9/239.6 kB 901.1 kB/s eta 0:00:01
#    ---------------------------------------  235.5/239.6 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 239.6/239.6 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

doc = Document('Análisis de la UX.docx')

for paragraph in doc.paragraphs:
    print(paragraph.text)
# Out:
# INTRODUCCIÓN Y JUSTIFICACIÓN
# El negocio de banquetes es una parte integral de la industria de la hospitalidad que ha experimentado un crecimiento constante en las últimas décadas. Los banquetes se han convertido en una opción popular para una amplia gama de eventos, desde bodas y celebraciones familiares hasta conferencias y eventos corporativos.
# Importancia del Negocio de Banquetes
# El negocio de banquetes desempeña un papel vital en la industria de la hospitalidad y la economía en general. Aporta una gran cantidad de ingresos, crea empleos y fomenta el turismo. Los banquetes son una opción popular para celebrar eventos especiales y reunir a personas, lo que contribuye a la cohesión social y fortalece los lazos familiares y comerciales. Además, los banquetes ofrecen una plataforma para mostrar la cultura, la gastronomía y la hospitalidad de una región, lo que puede atraer a turistas y promover el turismo. Las tendencias actuales han transformado el negocio de banquetes en varios aspectos. Por ejemplo, la sostenibilidad se ha vuelto una preocupación importante, y los banquetes han respondido al ofrecer opciones de alimentos orgánicos y sostenibles, así como reduciendo el desperdicio de alimentos y plásticos de un solo uso.
# La tecnología también ha tenido un impacto significativo. La reserva en línea y la gestión de eventos, la visualización de espacios en 3D y las aplicaciones móviles han facilitado la planificación de eventos y mejorado la experiencia del cliente.
# Con lo anterior mencionado, podemos destacar la importancia que las aplicaciones y páginas web tienen a la hora de poder brindar un servicio de calidad a los clientes ofreciendo a ellos la oportunidad de realizar reservas de pedidos y personalización de estos mismos, debido a esto, hemos decidido desarrollar una aplicación web para banquetes y reservaciones, la cual proveerá de muchas herramientas útiles a los clientes haciendo su proceso de reservación y selección de menú mucho más cómoda. Por lo que sin duda a medida que la industria evoluciona, los profesionales de banquetes deben adaptarse a las tendencias actuales, como la sostenibilidad y la tecnología, para seguir siendo relevantes y competitivos en el mercado.
# Las aplicaciones web permiten automatizar muchas tareas dentro del negocio de banquetes, desde la gestión de reservas hasta la administración de inventarios y la planificación de eventos. Esto no solo ahorra tiempo, sino que también reduce errores humanos y mejora la eficiencia operativa. Nuestra app pretende ser un sistema de gestión de eventos y software de reservas en línea pueden ayudar a rastrear y programar eventos de manera eficaz, asignar recursos y mantener un registro de las preferencias de los clientes. Esto conduce a una mayor productividad y una mejor experiencia para el cliente, lo que es fundamental en un negocio centrado en el servicio.
#
# BRIEFING
#
# Nombre del Proyecto: Delicias Cancún – Banquetes y Comidas
#
# Objetivo del Proyecto: Desarrollar una página web interactiva y fácil de usar que permita a los usuarios buscar, visualizar, reservar y programar banquetes y fechas de sus eventos. La página web debe brindar a los clientes una experiencia eficiente y atractiva al reservar sus eventos y banquetes.
#
# Público Objetivo:
# - Personas que buscan comidas o banquetes para sus eventos como bodas, celebraciones familiares, fiestas corporativas, etc.
# - Empresas y organizaciones que requieran proveedores de comidas o banquetes para eventos masivos o celebraciones importantes como aniversarios, eventos particulares de la empresa, etc.
#
# Funcionalidades Clave:
# 1. Galería de Fotos: Una sección de galería de fotos que muestre imágenes de los banquetes y menús disponibles y banquetes anteriores para ayudar a los clientes a motivarse a reservar para sus eventos.
# 2. Calendario de Disponibilidad: Un calendario interactivo que muestra las fechas disponibles y las fechas reservadas para eventos, pudiendo los clientes reservar en fechas disponibles en los siguientes días o meses.
# 3. Formulario de Reserva: Un formulario de reserva en línea que permita a los clientes proporcionar detalles de su evento, incluyendo fecha, número de invitados, preferencias de alimentos, servicios adicionales, etc.
# 4. Proceso de Pago en Línea: La opción de pagar en línea de forma segura para confirmar la reserva o incluso poder realizar un monto minimo requerido al momento de crear la reserva para que esta sea aceptada en ese momento.
# 5. Contáctanos: Información de contacto clara y un formulario de contacto para consultas y soporte.
# 6. Sección de Testimonios: Testimonios de clientes satisfechos que respalden la calidad de nuestros servicios.
#
# Diseño y Estética:
# El diseño de la página web debe ser elegante y reflejar la atmósfera de eventos y banquetes. Se debe utilizar una paleta de colores apropiada y fotos de alta calidad que muestren los espacios y la comida de manera atractiva.
# El enfoque visual del Flat Design para esta aplicación web buscará ofrecer una experiencia de usuario intuitiva, moderna y atractiva, sin distracciones visuales innecesarias, permitiendo a los usuarios navegar fácilmente a través del proceso de reserva de banquetes y comidas para eventos especiales. La interfaz estará compuesta por elementos gráficos simples, colores sólidos y un diseño limpio que enfatizará la usabilidad y la funcionalidad. Los iconos y botones serán claros y fáciles de entender, con formas geométricas sencillas y una paleta de colores vibrantes pero equilibrados. La tipografía será clara, legible y de tamaño apropiado, facilitando la comprensión de la información sobre menús, ubicaciones y disponibilidad de reservas.
#
# Tecnología:
# Para el desarrollo de la página web, se emplearán tecnologías de vanguardia y se hará un uso efectivo del Framework Angular, lo que garantizará una experiencia de usuario de alto nivel y un funcionamiento eficiente. Las tecnologías y enfoques específicos incluirán:
# Front-End con Angular para desarrollar la interfaz de usuario altamente interactiva y receptiva de la página web. Angular permite crear una experiencia fluida para el usuario, con una estructura modular que facilita la gestión de componentes.
# Lenguajes Web: HTML5, CSS3 y JavaScript serán los lenguajes base para la creación de la interfaz de usuario, garantizando una presentación atractiva y una experiencia de usuario sin problemas.
# Base de Datos: Se utilizará una base de datos en tiempo real como Firebase, eficiente para gestionar la información sobre las reservas y eventos programados, garantizando la integridad y seguridad de los datos de los clientes.
# Diseño Responsivo: Angular permitirá crear un diseño completamente responsivo que se adapte a diferentes tamaños de pantalla y dispositivos, lo que es esencial en la era móvil actual.
#
# Optimización Móvil:
# La página web será totalmente receptiva y funcionar sin problemas en dispositivos móviles, como teléfonos inteligentes y tabletas.
# Métricas de Éxito:
# El éxito del proyecto se medirá por el aumento en las reservas de banquetes y eventos a través de la página web, la satisfacción del cliente, y el tiempo medio de respuesta a las consultas de los clientes.
# Este briefing sienta las bases para el desarrollo de una página web efectiva para la reserva de banquetes y comidas para eventos. Asegurar una experiencia de usuario fluida y una presentación atractiva de los servicios es esencial para el éxito de la página web.
#
# SEMIOSIS INSTITUCIONAL
#
# Nombre: JAMJ Software’s.
#
# Tipo de negocio: Empresa de desarrollo de Software a la Medida.
#
# Giro de la marca: Sector de la Tecnología y la Informática.
#
# Target: Empresas y Organizaciones, Startups, Emprendedores individuales, Gobiernos y Organismos públicos, Instituciones educativas, Empresas de sectores específicos, Empresas en crecimiento, Profesionales independientes, Clientes internacionales.
#
# Escala: Local
#
# Ubicación: N/A
#
# Servicios: Desarrollo de Software Personalizado, Software a la Medida, Diseño de Interfaces de Usuario (UI), Programación y Desarrollo, Implementación y Soporte.
#
# Posicionamiento: PYME
#
# IDENTIDAD
# JAMJ Software’s es una empresa de calidad en desarrollo de software a medida. Nuestra pasión por la tecnología y la creatividad nos impulsa a diseñar soluciones únicas para nuestros clientes. Con un equipo de expertos en programación y diseño, estamos comprometidos con ofrecer software de calidad que responda a las necesidades específicas de cada cliente.
# Valores Corporativos:
# Innovación: Abrazamos la innovación y la tecnología de vanguardia para crear soluciones que marcan la diferencia.
# Colaboración: Creemos en el poder de la colaboración y trabajamos estrechamente con nuestros clientes para lograr sus objetivos.
# Excelencia: Nos esforzamos por la excelencia en cada línea de código que escribimos y en cada diseño que creamos.
# Adaptabilidad: Somos flexibles y nos adaptamos a los cambios tecnológicos y a las necesidades cambiantes de nuestros clientes.
#
# PARADIGMA
# Realizando una investigación por medio de internet encontramos a tres empresas que son competencias directas de nuestro proyecto orientado a los servicios de banquetes y comidas para eventos, por lo que a continuación mencionamos cuales son estas, sus páginas web y los servicios más importantes que ofrecen, comparándolas unas con otras.
# Notamos un rasgo general entre estas tres páginas web, las cuales realmente se podrían denominar como paginas estáticas ya que cuyo contenido es fijo y no cambia automáticamente según las acciones del usuario o la información almacenada en sus bases de datos, sino que permanece como únicamente una página informativa y de contacto para aquellos que estén interesados en el servicio, el cual se dará a posterior por otros medios dejando a la página web, no como una aplicación sino un medio más por el que los clientes pueden obtener la información de contacto de ellos, medios que fácilmente tambien podrían ser Redes Sociales, Periódicos, Anuncios Online, Anuncios en TV, etc. Y de esta manera se desaprovecha está herramienta tecnológica que podría fácilmente automatizar procesos y realizar mucho más.
# A continuación, la comparación de 3 competencias directas para el proyecto de Delicias Cancún:
#
#
# Las tres empresas, "Taquizas Cancún", "ChefToGo" y "DELEITE", ofrecen servicios de alimentos y catering para eventos, pero tienen algunas diferencias clave y similitudes. A continuación, presentamos las más claves:
#
# Diferencias:
# Especialización y menús: Taquizas Cancún se especializa en taquizas y ofrece un servicio de mesa decorada con motivos mexicanos. ChefToGo se centra en chef a domicilio y catering para una variedad de eventos. DELEITE se enfoca en catering para empresas, grupos de incentivos, tours y fiestas temáticas. Las diferencias radican en su especialización y los tipos de menús que ofrecen.
# Público objetivo: Cada empresa puede tener un público objetivo diferente. Taquizas Cancún puede dirigirse a personas que desean comida mexicana en eventos informales, ChefToGo a aquellos que buscan experiencias culinarias más personalizadas, y DELEITE a empresas y turistas que requieren servicios de catering en un contexto diferente.
# Ubicación geográfica: Puede haber diferencias en las áreas geográficas que atienden. Taquizas Cancún parece estar orientado a Cancún, mientras que las otras dos empresas pueden ofrecer servicios en ubicaciones más amplias como por ejemplo en todo Quintana Roo.
# Estilos de IU: En cuanto a sus páginas web, las 3 cuentan con estilos de interfaz de usuario completamente diferentes, debido a que cada cual cuenta con un público objetivo totalmente diferente, a pesar de esto, la que se podría quedar detrás en cuanto IU/UX sería DELEITE ya que la interfaz puede no ser tan agradable a primera vista y al continuar explorando el sitio pueden surgir más fallas en la arquitectura de la información.
#
# Similitudes:
# Servicio de catering: Las tres empresas ofrecen servicios de catering para eventos, lo que significa que pueden proporcionar alimentos y bebidas para una variedad de ocasiones.
# Servicio personalizado: Tanto ChefToGo como DELEITE mencionan servicios personalizados. Esto indica que pueden adaptar sus menús y servicios a las necesidades específicas de los clientes.
# Páginas Informativas: Las 3 páginas pueden fácilmente contar como paginas o sitios web informativos para estas tres empresas de giro gastronómico; Debido a que en ninguna hay alguna función especial para realizar una cotización en tiempo real o para reservar fechas de sus eventos o servicios requeridos, por lo que a continuación de finamos cual es el valor agregado el cual es altamente notorio en nuestro proyecto.
#
# Valor Agregado
# Para destacar y ofrecer un valor agregado en nuestra aplicación web que permitirá cotizaciones y reservas de banquetes y comidas en comparación con las 3 empresas mencionadas (Taquizas Cancún, ChefToGo y DELEITE), consideramos importantes las siguientes características y beneficios:
# Personalización de menús en tiempo real: Permitirá a los usuarios personalizar sus menús y servicios en tiempo real. Esto incluiría opciones para elegir platos específicos, adaptar las porciones, ajustar los ingredientes y hacer cambios según las preferencias dietéticas.
# Visualización de precios en tiempo real: La aplicación podría mostrar el costo estimado a medida que los usuarios personalizan sus pedidos. Esto brinda transparencia y ayuda a los clientes a tomar decisiones informadas.
# Calendario de disponibilidad en tiempo real: Ofrece a los usuarios un calendario interactivo que muestra la disponibilidad de fechas y horarios para sus eventos. Esto facilita la selección de fechas convenientes y evita conflictos de programación con los chefs y cocineros de la empresa cliente.
# Herramienta de cotización instantánea: Proporciona a los usuarios la capacidad de recibir cotizaciones instantáneas en función de sus selecciones de menú, los cuales pueden ser menús armados de manera predeterminada por el negocio o menús personalizados por los usuarios en función de tamaño del evento y otros detalles. Esto agiliza el proceso de toma de decisiones y ayuda a los encargados del a tomar otras prioridades como la calidad del servicio a ofrecer.
#
# Al proporcionar una plataforma en línea que simplifica y agiliza el proceso de cotización y reserva de servicios de banquetes y comidas, podemos ofrecer un valor agregado al brindar comodidad, transparencia y personalización a tus clientes, lo que puede marcar la diferencia en comparación con las empresas tradicionales y su modo de operar por medio de contacto tradicional y sin procesos automatizados.
#
# Medios
# Nuestro proyecto se puede difundir en una variedad de medios para alcanzar a potenciales usuarios e interesados. Aquí algunos de ellos en donde se podría difundir este proyecto:
#
# Redes Sociales: Utilizar plataformas como Facebook, Instagram, Twitter, LinkedIn, y otras redes relevantes para compartir anuncios, publicaciones informativas, imágenes y videos relacionados con la aplicación. También se pueden utilizar anuncios pagados para llegar a audiencias específicas.
#
# Publicidad Online: Utilizar Google Ads u otros servicios de publicidad online para promocionar la aplicación web a través de anuncios de búsqueda o banners en sitios relevantes.
#
#
#
#
#
# IMAGEN INSTITUCIONAL
#
#
# TEXTO DE IDENTIDAD
#
# “Delicias Cancún: Tu Plataforma Personalizada para Banquetes y Comidas”
#
# En DELICIAS, estamos comprometidos en brindarte una experiencia única en la planificación de banquetes y comidas, todo a través de nuestra innovadora aplicación web. Creemos en la personalización, la simplicidad y la comodidad, y aquí está nuestra identidad en línea con esos valores. Nuestra visión en DELICIAS es revolucionar la forma en que se planifican banquetes y comidas a través de nuestra aplicación web. Amamos a usuarios, por eso brindamos la capacidad de personalizar cada aspecto de sus eventos de manera sencilla y accesible. Queremos que cada cliente experimente la libertad de diseñar su banquete perfecto, desde la elección de platos exquisitos hasta la adaptación de menús para satisfacer sus necesidades específicas. Con nuestro enfoque en la cotización instantánea y la disponibilidad en tiempo real, buscamos simplificar el proceso de reserva y proporcionar transparencia en cada paso.
#
#
#
# PERFIL SOCIODEMOGRÁFICO
#
# Edad:
# Jóvenes adultos (27 - 40 años) que están planificando bodas, despedidas de soltero/a, cumpleaños y otros eventos especiales.
# Adultos de mediana edad (35-60 años) que organizan reuniones corporativas, eventos empresariales y celebraciones familiares.
# Género:
# No hay un género específico, ya que tanto hombres como mujeres pueden estar interesados en planificar eventos y banquetes.
# Estado Civil:
# Solteros, parejas casadas y personas en relaciones comprometidas, ya que los eventos pueden variar desde bodas hasta reuniones corporativas y celebraciones familiares.
# Nivel de Ingresos:
# Clases medias y medias-alta, ya que los eventos que implican banquetes y comidas personalizadas tienden a ser una inversión en experiencias especiales.
# Ubicación Geográfica:
# Principalmente Cancún, pero tambien el servicio se extiende a sus al rededores cercanos, como por ejemplo Playa del Carmen, Puerto Morelos y Tulum.
# Ocupación:
# Profesionales, ejecutivos, emprendedores y personas que trabajan en cualquier sector con la capacidad de pagar el servicio.
# Intereses:
# Personas interesadas en un servicio de calidad, respuesta rápida por parte de la aplicación web y personas interesadas en los servicios de catering y banquetes.
# Necesidades Específicas:
# Personas que valoran la personalización, la comodidad y la transparencia en el momento de realizar sus reservaciones de comidas y banquetes para eventos.
# Clientes que buscan opciones de menús regulares para eventos especiales.
# Empresas que requieren servicios de catering para reuniones corporativas y eventos.
# TIPO DE CONSUMIDOR
# El tipo de consumidor estimado para este proyecto principalmente serían aquellos que están comprometidos y a punto de realizar sus bodas y padres en busca de comidas para fechas importantes de sus hijas como por ejemplo XV años, de los cuales son los tipos de eventos más comunes en los que se suele ofrecer el servicio de DELICIAS; Al igual que estos ya mencionados, adicionalmente y no con la misma frecuencia de uso del servicio pero siendo tambien relevantes podemos mencionar a personas que planean eventos personales, como aniversarios, despedidas de soltero/a y otras celebraciones familiares y empresas que organizan reuniones corporativas, conferencias, eventos de formación y comidas de negocios.
#
# PROPÓSITO
# Objetivos
#
# A continuación, se muestra una imagen que describe el proceso de la UX el cual cuenta con 5 fases principales (las cuales son Planeación, Análisis, Diseño, Prototipado y Testeo) para lograr un correcto desarrollo de los objetivos que veremos seguido de está misma.
#
#
#
#
# Desarrollar una interfaz de usuario (UI) intuitiva y atractiva Flat Design para incluir la tipografía adecuada, pocos elementos con los que los usuarios puedan distraerse y conformando una estructura de la información correcta para la navegación dentro de la aplicación.
#
# Mejorar la velocidad de carga de la aplicación web para una experiencia más rápida y eficiente por medio del uso de las tecnologías de desarrollo que se adecuan de mejor manera al proyecto, en este caso el Framework Angular que integra tecnologías de desarrollo web (HTML, SCSS, TypeScript).
#
#
# Garantizar una experiencia de usuario sin problemas en dispositivos móviles adaptando la aplicación web para que sea completamente receptiva y funcione de manera eficiente en smartphones y tabletas integrando diseño responsivo con Angular.
#
# Desarrollar una función de búsqueda avanzada que permita a los usuarios buscar menús específicos, platos y opciones comúnmente escogidas de manera rápida y precisa, mejorando así la usabilidad de la aplicación web.
#
#
#
# Simplificar el proceso de personalización de menús para los usuarios reduciendo el número de pasos necesarios para personalizar un menú, mejorando la usabilidad y la experiencia del usuario.
#
# Implementar un sistema de cotización en tiempo real que sea intuitivo y preciso basado en los menús seleccionados (incluyendo los personalizados), los precios de cada orden y el número de personas a considerar, ofreciendo precios precisos al instante y que sea fácil de usar para los usuarios.
#
# Garantizar una experiencia de reserva de fechas sencilla y efectiva por medio de un sistema de formularios con un calendario de reservas interactivo que permita a los usuarios verificar la disponibilidad y realizar reservas en pocos pasos de manera sencilla.
#
#
# Implementar un servicio de atención al cliente en tiempo real para resolver preguntas y problemas de los usuarios con un chat en vivo o soporte en línea para brindar asistencia rápida y efectiva a los usuarios.
#
# Fomentar la retroalimentación de los usuarios para la mejora continua, estableciendo un sistema de comentarios y encuestas que invite a los usuarios a proporcionar sus opiniones y sugerencias, y actuar en consecuencia.
#
# Mejorar la seguridad de los datos del usuario para generar confianza, implementando medidas de seguridad adicionales, como la encriptación de datos y las políticas de privacidad claras, para proteger la información del usuario y fortalecer la confianza en la plataforma.
#
# Cronograma de actividades
# DESARROLLO Y ANÁLISIS DEL MOMENTO
# Nuestro tipo de consumidor es basado para clientes que festejen algún evento importante para una empresa, fiesta, juntas o algún evento corporativo, con lo cual el rango de nuestros consumidores radica entre los 30 años a 67 años y como los consumidores jóvenes de 25 años a 40 años que festejan sus cumpleaños, eventos recreativos, bodas entre otros, con lo cual debemos empatizar con el cliente en el ámbito económico, confiabilidad, eficaz y una buena imagen.
# Es importante tener los primeros pasos en identificar cómo el usuario interactúa con nuestra aplicación web, puede ser en el apartado navegación, menú de guisos o en la reservación del cáterin, esto implica el desarrollo detallado de la aplicación web en cuanto la interacción que tiene durante su experiencia en la interfaz (UX), con lo cual nos proporciona un análisis detallado del momento, que nos da errores, optimalización de la interfaz, tiempo detallado en que el usuario entienda la interfaz y el diseño de la aplicación, con lo cual nosotros recaudamos datos importantes para poder mejorar y obtener implementaciones de nuestra interfaz.
# Con lo cual nosotros podemos dar un mejor desarrollo de la aplicación mediante la recopilación de datos de los usuarios, personalizaciones y una interacción continua.
# ANÁLISIS FODA
# Tras analizar las características internas y su situación externa, se obtuvieron las siguientes características utilizando la técnica del análisis FODA:
#
# DESARROLLO DEL THE REASON WHY?
# El “The Reason Why?” es la razón por la que la empresa existe y lo que la hace única. En el caso de nuestra empresa, el “The Reason Why?” podría ser:
# “Ofrecer una experiencia gastronómica memorable para todos nuestros clientes.”
# Este, es claro, conciso y relevante para la empresa. También es inspirador y motivador para los colaboradores y los clientes.
#
# PRESUPUESTO DEL PROYECTO
#
# Costo total
# El costo total del proyecto es de $610,000. Este costo incluye los honorarios de los desarrolladores, diseñadores y otros profesionales involucrados en el proyecto, así como los costos de los materiales, herramientas y software necesarios para llevar a cabo este proyecto.
#
# MOBILE FIRST
#
# A continuación, presentamos nuestros wireframes en base a todas las especificaciones que hemos realizado a lo largo de este documento, esperando contar con un flujo de navegación satisfactorio, tomando muy en cuenta el diseño presentado con anterioridad para que los usuarios puedan navegar sin complicaciones de manera intuitiva y efectiva.
# Link: https://miro.com/welcomeonboard/dnQwZFEyQU0yTU0yTnVnRkVXRzZkcml6MDRFTUhweUg4WG14MHBObFA4OWtLbkVvSXFrcjZTRnRnT1hkMWtMNnwzNDU4NzY0NTY4MjA4NTkyODI1fDI=?share_link_id=328614536230
#
#
#
#
#
#
#
#
# FIN DE ESTE DOCUMENTO. GRACIAS
